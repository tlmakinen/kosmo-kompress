# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %%
# !pip install -q jax==0.2.11
# Out:
#      |████████████████████████████████| 596 kB 5.3 MB/s
#   Building wheel for jax (setup.py) ... done

# %%
# !pip install tensorflow-probability
# Out:
# Requirement already satisfied: tensorflow-probability in /usr/local/lib/python3.7/dist-packages (0.13.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability) (0.1.6)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability) (1.3.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability) (1.19.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability) (4.4.2)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability) (0.4.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability) (1.15.0)

# %%
import tensorflow_probability as tfp
print(tfp.__version__)
tfd = tfp.distributions
tfb = tfp.bijectors
# Out:
# 0.13.0

# %%
# !pip install -q imnn
# Out:
#      |████████████████████████████████| 127 kB 5.1 MB/s

# %%
import jax.numpy as np
from jax import grad, jit, vmap
from jax import random
import jax

#print('jax version: ', jax.__version__)

# for model stuff
import jax.experimental.optimizers as optimizers
import jax.experimental.stax as stax


# tensorflow-prob VANILLA
tfd = tfp.distributions
tfb = tfp.bijectors

# tensorflow-prob-JAX
import tensorflow_probability.substrates.jax as tfpj

tfdj = tfpj.distributions
tfbj = tfpj.bijectors

# matplotlib stuff
import matplotlib.pyplot as plt
from scipy.linalg import toeplitz
import seaborn as sns
sns.set()


# for imnn
import imnn
import imnn.lfi

rng = random.PRNGKey(2)

# %%
from jax.lib import xla_bridge
print(xla_bridge.get_backend().platform)
# Out:
# gpu

# %%
n_s = 5000
n_d = n_s

n_params = 2
n_summaries = n_params

input_shape = (10,)

# %%
def true_F(Σ, n_d):
    return - np.array([[- n_d / Σ, 0.], [0., - n_d / (2. * Σ**2.)]])

# %%
@jit
def simulator(key, θ):
    return np.exp(θ[0] + jax.random.normal(key, shape=input_shape) * np.sqrt(θ[1]))

# %%
θ_fid = np.array([0., 0.5])

# %%
rng = jax.random.PRNGKey(10)
rng, model_key, fit_key = jax.random.split(rng, num=3)

# %%
widths =[50, 128, 500, 1000, 2000]
L = 3
def build_model(L, width, activation=stax.LeakyRelu, n_summaries=2):
  layers = []
  for i in range(L):
    layers.append(stax.Dense(width))
    layers.append(activation)
  
  layers.append(stax.Dense(n_summaries))

  return stax.serial(*layers)

models = [build_model(L, w, stax.Relu) for w in widths]
opts = [optimizers.adam(step_size=1e-3) for l in range(len(widths))]
model_keys = jax.random.split(rng, num=len(widths))

# %%
IMNNs = [imnn.SimulatorIMNN(
    n_s=n_s, n_d=n_d, n_params=n_params, n_summaries=n_summaries,
    input_shape=input_shape, θ_fid=θ_fid, model=models[w],
    optimiser=opts[w], key_or_state=model_keys[w],
    simulator=simulator) for w in range(len(widths))
]

# %%
λ = 10.
ϵ = 0.1

# %%
fit_keys = jax.random.split(rng, num=len(widths))
for i,w in enumerate(widths):
  print("fitting imnn with nn width %d"%(w))
  IMNNs[i].fit(λ, ϵ, rng=fit_keys[i], print_rate=None, best=True, patience=100)
# Out:
# fitting imnn with nn width 50
# fitting imnn with nn width 128
# fitting imnn with nn width 500
# fitting imnn with nn width 1000
# fitting imnn with nn width 2000

# %%
import seaborn as sns
pal = sns.color_palette("magma")
colors = pal.as_hex() + ["blue", "orange", "purple"]
ax = IMNNs[0].plot(expected_detF=np.linalg.det(true_F(0.5, 10)))
for i,w in enumerate(widths[:]):
  IMNNs[i].plot(ax=ax, colour=colors[i], label="width %d"%(w))
# ax[0].set_yscale("log")

# %%
for i in IMNNs:
  print(np.linalg.det(i.F))
# Out:
# 134.88799
# 126.49066
# 154.44151
# 130.51642
# 144.6956

# %%
np.linalg.det(true_F(0.5, 10))
# Out:
# DeviceArray(400.00003, dtype=float32)

# %%
widths =[50, 128, 500]
L = 4

act = stax.Tanh

models = [build_model(L, w, act) for w in widths]
opts = [optimizers.adam(step_size=1e-3) for l in range(len(widths))]
model_keys = jax.random.split(rng, num=len(widths))

IMNNs = [imnn.SimulatorIMNN(
    n_s=n_s, n_d=n_d, n_params=n_params, n_summaries=n_summaries,
    input_shape=input_shape, θ_fid=θ_fid, model=models[w],
    optimiser=opts[w], key_or_state=model_keys[w],
    simulator=simulator) for w in range(len(widths))
]

fit_keys = jax.random.split(rng, num=len(widths))
for i,w in enumerate(widths):
  print("fitting selu imnn with nn width %d"%(w))
  IMNNs[i].fit(λ, ϵ, rng=fit_keys[i], print_rate=None, best=True, patience=100)
# Out:
# fitting selu imnn with nn width 50
# fitting selu imnn with nn width 128
# fitting selu imnn with nn width 500

# %%
ax = IMNNs[0].plot(expected_detF=np.linalg.det(true_F(0.5, 10)))
for i,w in enumerate(widths[:]):
  IMNNs[i].plot(ax=ax, colour=colors[i], label="width %d"%(w))

plt.title('softplus networks')
plt.show()

# %%
for i in IMNNs:
  print(np.linalg.det(i.F))
# Out:
# 152.89565
# 203.8936
# 173.69649
